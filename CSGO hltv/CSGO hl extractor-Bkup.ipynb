# %%
pip install lxml
# Out:
# Collecting lxml
#   Downloading https://files.pythonhosted.org/packages/55/6f/c87dffdd88a54dd26a3a9fef1d14b6384a9933c455c54ce3ca7d64a84c88/lxml-4.5.1-cp36-cp36m-manylinux1_x86_64.whl (5.5MB)
#      |████████████████████████████████| 5.5MB 6.3MB/s eta 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-4.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading https://files.pythonhosted.org/packages/66/25/ff030e2437265616a1e9b25ccc864e0371a0bc3adb7c5a404fd661c6f4f6/beautifulsoup4-4.9.1-py3-none-any.whl (115kB)
#      |████████████████████████████████| 122kB 5.5MB/s eta 0:00:01
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Downloading https://files.pythonhosted.org/packages/6f/8f/457f4a5390eeae1cc3aeab89deb7724c965be841ffca6cfca9197482e470/soupsieve-2.0.1-py3-none-any.whl
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.9.1 soupsieve-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install html5lib
# Out:
# Requirement already satisfied: html5lib in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.9999999)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from html5lib) (1.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests) (2.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd
import urllib.request
import re

# %%
masterlink = 'https://www.hltv.org/results?offset=7000'
mastersource = requests.get(masterlink).text
mastersoup = BeautifulSoup(mastersource,'lxml')
for foxtrot in mastersoup.find_all(class_='results-holder'):
    print(foxtrot.prettify())
# Out:
# <div class="results-holder">
#  <div class="results-all" data-zonedgrouping-group-classes="results-sublist" data-zonedgrouping-headline-classes="standard-headline" data-zonedgrouping-headline-format="'Results for' MMMM do y">
#   <div class="results-sublist">
#    <span class="standard-headline">
#     Results for August 10th 2019
#    </span>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565433786000">
#     <a class="a-reset" href="/matches/2335201/espada-vs-elquvet-msi-mga-2019-cis-closed-qualifier">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            Espada
#           </div>
#           <img alt="Espada" class="team-logo" src="https://static.hltv.org/images/team/logo/8669" title="Espada"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           2
#          </span>
#          -
#          <span class="score-lost">
#           0
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="eL'quvet" class="team-logo" src="https://static.hltv.org/images/team/logo/7427" title="eL'quvet"/>
#           <div class="team">
#            eL'quvet
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="MSI MGA 2019 CIS Closed Qualifier" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4711.png" title="MSI MGA 2019 CIS Closed Qualifier"/>
#          <span class="event-name">
#           MSI MGA 2019 CIS Closed Qualifier
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565427243000">
#     <a class="a-reset" href="/matches/2335367/e-vian-vs-christon-wesg-2019-laos-regional-finals">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            E-Vian
#           </div>
#           <img alt="E-Vian" class="team-logo" src="https://static.hltv.org/images/team/logo/10247" title="E-Vian"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           2
#          </span>
#          -
#          <span class="score-lost">
#           0
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="Christon " class="team-logo" src="https://static.hltv.org/images/team/logo/10248" title="Christon "/>
#           <div class="team">
#            Christon
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="WESG 2019 Laos Regional Finals" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4797.png" title="WESG 2019 Laos Regional Finals"/>
#          <span class="event-name">
#           WESG 2019 Laos Regional Finals
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565420316000">
#     <a class="a-reset" href="/matches/2335392/tyloo-vs-lynn-vision-dreamhack-masters-malm-2019-china-closed-qualifier">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            TYLOO
#           </div>
#           <img alt="TYLOO" class="team-logo" src="https://static.hltv.org/images/team/logo/4863" title="TYLOO"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           2
#          </span>
#          -
#          <span class="score-lost">
#           0
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="Lynn Vision" class="team-logo" src="https://static.hltv.org/images/team/logo/8840" title="Lynn Vision"/>
#           <div class="team">
#            Lynn Vision
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="DreamHack Masters Malmö 2019 China Closed Qualifier" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4793.png" title="DreamHack Masters Malmö 2019 China Closed Qualifier"/>
#          <span class="event-name">
#           DreamHack Masters Malmö 2019 China Closed Qualifier
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565412903000">
#     <a class="a-reset" href="/matches/2335378/8easy-vs-very1z-dreamhack-masters-malm-2019-china-closed-qualifier">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            8EASY
#           </div>
#           <img alt="8EASY" class="team-logo" src="https://static.hltv.org/images/team/logo/9906" title="8EASY"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           2
#          </span>
#          -
#          <span class="score-lost">
#           0
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="Very1z" class="team-logo" src="https://static.hltv.org/images/team/logo/10073" title="Very1z"/>
#           <div class="team">
#            Very1z
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="DreamHack Masters Malmö 2019 China Closed Qualifier" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4793.png" title="DreamHack Masters Malmö 2019 China Closed Qualifier"/>
#          <span class="event-name">
#           DreamHack Masters Malmö 2019 China Closed Qualifier
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#   </div>
#   <div class="results-sublist">
#    <span class="standard-headline">
#     Results for August 9th 2019
#    </span>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565382765000">
#     <a class="a-reset" href="/matches/2335372/vexed-vs-gambit-youngsters-lootbet-season-3">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team">
#            Vexed
#           </div>
#           <img alt="Vexed" class="team-logo" src="https://static.hltv.org/images/team/logo/8020" title="Vexed"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-lost">
#           0
#          </span>
#          -
#          <span class="score-won">
#           2
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="Gambit Youngsters" class="team-logo" src="https://static.hltv.org/images/team/logo/9976" title="Gambit Youngsters"/>
#           <div class="team team-won">
#            Gambit Youngsters
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="LOOT.BET Season 3" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4760.png" title="LOOT.BET Season 3"/>
#          <span class="event-name">
#           LOOT.BET Season 3
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565372865000">
#     <a class="a-reset" href="/matches/2335374/illuminar-vs-havu-lootbet-season-3">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team">
#            Illuminar
#           </div>
#           <img alt="Illuminar" class="team-logo" src="https://static.hltv.org/images/team/logo/8813" title="Illuminar"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-lost">
#           0
#          </span>
#          -
#          <span class="score-won">
#           2
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="HAVU" class="team-logo" src="https://static.hltv.org/images/team/logo/7865" title="HAVU"/>
#           <div class="team team-won">
#            HAVU
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="LOOT.BET Season 3" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4760.png" title="LOOT.BET Season 3"/>
#          <span class="event-name">
#           LOOT.BET Season 3
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565368757000">
#     <a class="a-reset" href="/matches/2335371/tyloo-vs-vici-dreamhack-masters-malm-2019-china-closed-qualifier">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team">
#            TYLOO
#           </div>
#           <img alt="TYLOO" class="team-logo" src="https://static.hltv.org/images/team/logo/4863" title="TYLOO"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-lost">
#           1
#          </span>
#          -
#          <span class="score-won">
#           2
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="ViCi" class="team-logo" src="https://static.hltv.org/images/team/logo/7606" title="ViCi"/>
#           <div class="team team-won">
#            ViCi
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="DreamHack Masters Malmö 2019 China Closed Qualifier" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4793.png" title="DreamHack Masters Malmö 2019 China Closed Qualifier"/>
#          <span class="event-name">
#           DreamHack Masters Malmö 2019 China Closed Qualifier
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565354656000">
#     <a class="a-reset" href="/matches/2335365/8easy-vs-5power-dreamhack-masters-malm-2019-china-closed-qualifier">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team">
#            8EASY
#           </div>
#           <img alt="8EASY" class="team-logo" src="https://static.hltv.org/images/team/logo/9906" title="8EASY"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-lost">
#           1
#          </span>
#          -
#          <span class="score-won">
#           2
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="5POWER" class="team-logo" src="https://static.hltv.org/images/team/logo/7092" title="5POWER"/>
#           <div class="team team-won">
#            5POWER
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="DreamHack Masters Malmö 2019 China Closed Qualifier" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4793.png" title="DreamHack Masters Malmö 2019 China Closed Qualifier"/>
#          <span class="event-name">
#           DreamHack Masters Malmö 2019 China Closed Qualifier
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565343366000">
#     <a class="a-reset" href="/matches/2335370/jijiehao-vs-very1z-dreamhack-masters-malm-2019-china-closed-qualifier">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team">
#            JiJieHao
#           </div>
#           <img alt="JiJieHao" class="team-logo" src="https://static.hltv.org/images/team/logo/10245" title="JiJieHao"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-lost">
#           1
#          </span>
#          -
#          <span class="score-won">
#           2
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="Very1z" class="team-logo" src="https://static.hltv.org/images/team/logo/10073" title="Very1z"/>
#           <div class="team team-won">
#            Very1z
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="DreamHack Masters Malmö 2019 China Closed Qualifier" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4793.png" title="DreamHack Masters Malmö 2019 China Closed Qualifier"/>
#          <span class="event-name">
#           DreamHack Masters Malmö 2019 China Closed Qualifier
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565331412000">
#     <a class="a-reset" href="/matches/2335366/lynn-vision-vs-onethree-dreamhack-masters-malm-2019-china-closed-qualifier">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            Lynn Vision
#           </div>
#           <img alt="Lynn Vision" class="team-logo" src="https://static.hltv.org/images/team/logo/8840" title="Lynn Vision"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           2
#          </span>
#          -
#          <span class="score-lost">
#           1
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="OneThree" class="team-logo" src="https://static.hltv.org/images/team/logo/10022" title="OneThree"/>
#           <div class="team">
#            OneThree
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="DreamHack Masters Malmö 2019 China Closed Qualifier" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4793.png" title="DreamHack Masters Malmö 2019 China Closed Qualifier"/>
#          <span class="event-name">
#           DreamHack Masters Malmö 2019 China Closed Qualifier
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#   </div>
#   <div class="results-sublist">
#    <span class="standard-headline">
#     Results for August 8th 2019
#    </span>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565292235000">
#     <a class="a-reset" href="/matches/2335341/havu-vs-dreameaters-lootbet-season-3">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            HAVU
#           </div>
#           <img alt="HAVU" class="team-logo" src="https://static.hltv.org/images/team/logo/7865" title="HAVU"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           2
#          </span>
#          -
#          <span class="score-lost">
#           0
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="DreamEaters" class="team-logo" src="https://static.hltv.org/images/team/logo/8305" title="DreamEaters"/>
#           <div class="team">
#            DreamEaters
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="LOOT.BET Season 3" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4760.png" title="LOOT.BET Season 3"/>
#          <span class="event-name">
#           LOOT.BET Season 3
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565280541000">
#     <a class="a-reset" href="/matches/2335340/izako-boars-vs-gambit-youngsters-lootbet-season-3">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team">
#            Izako Boars
#           </div>
#           <img alt="Izako Boars" class="team-logo" src="https://static.hltv.org/images/team/logo/7681" title="Izako Boars"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-lost">
#           0
#          </span>
#          -
#          <span class="score-won">
#           2
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="Gambit Youngsters" class="team-logo" src="https://static.hltv.org/images/team/logo/9976" title="Gambit Youngsters"/>
#           <div class="team team-won">
#            Gambit Youngsters
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="LOOT.BET Season 3" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4760.png" title="LOOT.BET Season 3"/>
#          <span class="event-name">
#           LOOT.BET Season 3
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565278249000">
#     <a class="a-reset" href="/matches/2335254/dreameaters-vs-oneway-qiwi-teamplay-season-4">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team">
#            DreamEaters
#           </div>
#           <img alt="DreamEaters" class="team-logo" src="https://static.hltv.org/images/team/logo/8305" title="DreamEaters"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-lost">
#           0
#          </span>
#          -
#          <span class="score-won">
#           1
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="OneWay" class="team-logo" src="https://static.hltv.org/images/team/logo/10129" title="OneWay"/>
#           <div class="team team-won">
#            OneWay
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="QIWI Teamplay Season 4" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4771.png" title="QIWI Teamplay Season 4"/>
#          <span class="event-name">
#           QIWI Teamplay Season 4
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           -
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565271070000">
#     <a class="a-reset" href="/matches/2335339/unique-vs-offset-lootbet-season-3">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            Unique
#           </div>
#           <img alt="Unique" class="team-logo" src="https://static.hltv.org/images/team/logo/9287" title="Unique"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           2
#          </span>
#          -
#          <span class="score-lost">
#           0
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="OFFSET" class="team-logo" src="https://static.hltv.org/images/team/logo/8515" title="OFFSET"/>
#           <div class="team">
#            OFFSET
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="LOOT.BET Season 3" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4760.png" title="LOOT.BET Season 3"/>
#          <span class="event-name">
#           LOOT.BET Season 3
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565270944000">
#     <a class="a-reset" href="/matches/2335356/ex-mc-vs-rewound-esl-australia-nz-championship-season-9">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            ex-MC
#           </div>
#           <img alt="ex-MC" class="team-logo" src="https://static.hltv.org/images/team/logo/10244" title="ex-MC"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           2
#          </span>
#          -
#          <span class="score-lost">
#           1
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="rewound" class="team-logo" src="https://static.hltv.org/images/team/logo/10041" title="rewound"/>
#           <div class="team">
#            rewound
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="ESL Australia &amp; NZ Championship Season 9" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4741.png" title="ESL Australia &amp; NZ Championship Season 9"/>
#          <span class="event-name">
#           ESL Australia &amp; NZ Championship Season 9
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565270488000">
#     <a class="a-reset" href="/matches/2335360/very1z-vs-vici-dreamhack-masters-malm-2019-china-closed-qualifier">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team">
#            Very1z
#           </div>
#           <img alt="Very1z" class="team-logo" src="https://static.hltv.org/images/team/logo/10073" title="Very1z"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-lost">
#           0
#          </span>
#          -
#          <span class="score-won">
#           2
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="ViCi" class="team-logo" src="https://static.hltv.org/images/team/logo/7606" title="ViCi"/>
#           <div class="team team-won">
#            ViCi
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="DreamHack Masters Malmö 2019 China Closed Qualifier" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4793.png" title="DreamHack Masters Malmö 2019 China Closed Qualifier"/>
#          <span class="event-name">
#           DreamHack Masters Malmö 2019 China Closed Qualifier
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565262119000">
#     <a class="a-reset" href="/matches/2335359/tyloo-vs-jijiehao-dreamhack-masters-malm-2019-china-closed-qualifier">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            TYLOO
#           </div>
#           <img alt="TYLOO" class="team-logo" src="https://static.hltv.org/images/team/logo/4863" title="TYLOO"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           2
#          </span>
#          -
#          <span class="score-lost">
#           0
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="JiJieHao" class="team-logo" src="https://static.hltv.org/images/team/logo/10245" title="JiJieHao"/>
#           <div class="team">
#            JiJieHao
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="DreamHack Masters Malmö 2019 China Closed Qualifier" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4793.png" title="DreamHack Masters Malmö 2019 China Closed Qualifier"/>
#          <span class="event-name">
#           DreamHack Masters Malmö 2019 China Closed Qualifier
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565254468000">
#     <a class="a-reset" href="/matches/2335358/5power-vs-onethree-dreamhack-masters-malm-2019-china-closed-qualifier">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            5POWER
#           </div>
#           <img alt="5POWER" class="team-logo" src="https://static.hltv.org/images/team/logo/7092" title="5POWER"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           2
#          </span>
#          -
#          <span class="score-lost">
#           1
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="OneThree" class="team-logo" src="https://static.hltv.org/images/team/logo/10022" title="OneThree"/>
#           <div class="team">
#            OneThree
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="DreamHack Masters Malmö 2019 China Closed Qualifier" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4793.png" title="DreamHack Masters Malmö 2019 China Closed Qualifier"/>
#          <span class="event-name">
#           DreamHack Masters Malmö 2019 China Closed Qualifier
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565242956000">
#     <a class="a-reset" href="/matches/2335357/8easy-vs-lynn-vision-dreamhack-masters-malm-2019-china-closed-qualifier">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            8EASY
#           </div>
#           <img alt="8EASY" class="team-logo" src="https://static.hltv.org/images/team/logo/9906" title="8EASY"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           2
#          </span>
#          -
#          <span class="score-lost">
#           1
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="Lynn Vision" class="team-logo" src="https://static.hltv.org/images/team/logo/8840" title="Lynn Vision"/>
#           <div class="team">
#            Lynn Vision
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="DreamHack Masters Malmö 2019 China Closed Qualifier" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4793.png" title="DreamHack Masters Malmö 2019 China Closed Qualifier"/>
#          <span class="event-name">
#           DreamHack Masters Malmö 2019 China Closed Qualifier
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#   </div>
#   <div class="results-sublist">
#    <span class="standard-headline">
#     Results for August 7th 2019
#    </span>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565211513000">
#     <a class="a-reset" href="/matches/2335243/forze-vs-optic-ggbet-new-york-invitational-esl-one-new-york-2019-qualifier">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team">
#            forZe
#           </div>
#           <img alt="forZe" class="team-logo" src="https://static.hltv.org/images/team/logo/8135" title="forZe"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-lost">
#           1
#          </span>
#          -
#          <span class="score-won">
#           2
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="OpTic" class="team-logo" src="https://static.hltv.org/images/team/logo/6615" title="OpTic"/>
#           <div class="team team-won">
#            OpTic
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="GG.BET New York Invitational - ESL One New York 2019 Qualifier" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4773.png" title="GG.BET New York Invitational - ESL One New York 2019 Qualifier"/>
#          <span class="event-name">
#           GG.BET New York Invitational - ESL One New York 2019 Qualifier
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-and-stars">
#           <div class="stars">
#            <i class="fa fa-star star">
#            </i>
#           </div>
#           <div class="map map-text">
#            bo3
#           </div>
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565197712000">
#     <a class="a-reset" href="/matches/2335242/optic-vs-big-ggbet-new-york-invitational-esl-one-new-york-2019-qualifier">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            OpTic
#           </div>
#           <img alt="OpTic" class="team-logo" src="https://static.hltv.org/images/team/logo/6615" title="OpTic"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           2
#          </span>
#          -
#          <span class="score-lost">
#           0
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="BIG" class="team-logo" src="https://static.hltv.org/images/team/logo/7532" title="BIG"/>
#           <div class="team">
#            BIG
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="GG.BET New York Invitational - ESL One New York 2019 Qualifier" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4773.png" title="GG.BET New York Invitational - ESL One New York 2019 Qualifier"/>
#          <span class="event-name">
#           GG.BET New York Invitational - ESL One New York 2019 Qualifier
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-and-stars">
#           <div class="stars">
#            <i class="fa fa-star star">
#            </i>
#           </div>
#           <div class="map map-text">
#            bo3
#           </div>
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565185786000">
#     <a class="a-reset" href="/matches/2335338/alternate-attax-vs-the-final-tribe-lootbet-season-3">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            ALTERNATE aTTaX
#           </div>
#           <img alt="ALTERNATE aTTaX" class="team-logo" src="https://static.hltv.org/images/team/logo/4501" title="ALTERNATE aTTaX"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           2
#          </span>
#          -
#          <span class="score-lost">
#           1
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="The Final Tribe" class="team-logo" src="https://static.hltv.org/images/team/logo/10040" title="The Final Tribe"/>
#           <div class="team">
#            The Final Tribe
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="LOOT.BET Season 3" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4760.png" title="LOOT.BET Season 3"/>
#          <span class="event-name">
#           LOOT.BET Season 3
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565184096000">
#     <a class="a-reset" href="/matches/2335241/forze-vs-winstrike-ggbet-new-york-invitational-esl-one-new-york-2019-qualifier">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            forZe
#           </div>
#           <img alt="forZe" class="team-logo" src="https://static.hltv.org/images/team/logo/8135" title="forZe"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           2
#          </span>
#          -
#          <span class="score-lost">
#           0
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="Winstrike" class="team-logo" src="https://static.hltv.org/images/team/logo/9183" title="Winstrike"/>
#           <div class="team">
#            Winstrike
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="GG.BET New York Invitational - ESL One New York 2019 Qualifier" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4773.png" title="GG.BET New York Invitational - ESL One New York 2019 Qualifier"/>
#          <span class="event-name">
#           GG.BET New York Invitational - ESL One New York 2019 Qualifier
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565181401000">
#     <a class="a-reset" href="/matches/2335330/rewound-vs-syf-esl-australia-nz-championship-season-9">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team">
#            rewound
#           </div>
#           <img alt="rewound" class="team-logo" src="https://static.hltv.org/images/team/logo/10041" title="rewound"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-lost">
#           0
#          </span>
#          -
#          <span class="score-won">
#           2
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="SYF" class="team-logo" src="https://static.hltv.org/images/team/logo/5607" title="SYF"/>
#           <div class="team team-won">
#            SYF
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="ESL Australia &amp; NZ Championship Season 9" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4741.png" title="ESL Australia &amp; NZ Championship Season 9"/>
#          <span class="event-name">
#           ESL Australia &amp; NZ Championship Season 9
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565176024000">
#     <a class="a-reset" href="/matches/2335329/madlikewizards-vs-ex-mc-esl-australia-nz-championship-season-9">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            madlikewizards
#           </div>
#           <img alt="madlikewizards" class="team-logo" src="https://static.hltv.org/images/team/logo/9275" title="madlikewizards"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           2
#          </span>
#          -
#          <span class="score-lost">
#           1
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="ex-MC" class="team-logo" src="https://static.hltv.org/images/team/logo/10244" title="ex-MC"/>
#           <div class="team">
#            ex-MC
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="ESL Australia &amp; NZ Championship Season 9" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4741.png" title="ESL Australia &amp; NZ Championship Season 9"/>
#          <span class="event-name">
#           ESL Australia &amp; NZ Championship Season 9
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565134949000">
#     <a class="a-reset" href="/matches/2335336/w7m-vs-reapers-brasil-game-show-2019">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            W7M
#           </div>
#           <img alt="W7M" class="team-logo" src="https://static.hltv.org/images/team/logo/8574" title="W7M"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           16
#          </span>
#          -
#          <span class="score-lost">
#           11
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="Reapers" class="team-logo" src="https://static.hltv.org/images/team/logo/9910" title="Reapers"/>
#           <div class="team">
#            Reapers
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="Brasil Game Show 2019" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4509.png" title="Brasil Game Show 2019"/>
#          <span class="event-name">
#           Brasil Game Show 2019
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           inf
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565132569000">
#     <a class="a-reset" href="/matches/2332599/red-canids-vs-detona-brasil-game-show-2019">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            RED Canids
#           </div>
#           <img alt="RED Canids" class="team-logo" src="https://static.hltv.org/images/team/logo/7176" title="RED Canids"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           16
#          </span>
#          -
#          <span class="score-lost">
#           11
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="DETONA" class="team-logo" src="https://static.hltv.org/images/team/logo/8902" title="DETONA"/>
#           <div class="team">
#            DETONA
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="Brasil Game Show 2019" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4509.png" title="Brasil Game Show 2019"/>
#          <span class="event-name">
#           Brasil Game Show 2019
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           inf
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565132558000">
#     <a class="a-reset" href="/matches/2335335/eox-vs-bulldozer-brasil-game-show-2019">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team">
#            EOX
#           </div>
#           <img alt="EOX" class="team-logo" src="https://static.hltv.org/images/team/logo/10119" title="EOX"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-lost">
#           12
#          </span>
#          -
#          <span class="score-won">
#           16
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="Bulldozer" class="team-logo" src="https://static.hltv.org/images/team/logo/9013" title="Bulldozer"/>
#           <div class="team team-won">
#            Bulldozer
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="Brasil Game Show 2019" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4509.png" title="Brasil Game Show 2019"/>
#          <span class="event-name">
#           Brasil Game Show 2019
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           trn
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565129796000">
#     <a class="a-reset" href="/matches/2335333/santos-vs-keyd-brasil-game-show-2019">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team">
#            Santos
#           </div>
#           <img alt="Santos" class="team-logo" src="https://static.hltv.org/images/team/logo/9213" title="Santos"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-lost">
#           13
#          </span>
#          -
#          <span class="score-won">
#           16
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="Keyd" class="team-logo" src="https://static.hltv.org/images/team/logo/6033" title="Keyd"/>
#           <div class="team team-won">
#            Keyd
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="Brasil Game Show 2019" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4509.png" title="Brasil Game Show 2019"/>
#          <span class="event-name">
#           Brasil Game Show 2019
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           nuke
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565129781000">
#     <a class="a-reset" href="/matches/2335334/w7m-vs-pain-brasil-game-show-2019">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            W7M
#           </div>
#           <img alt="W7M" class="team-logo" src="https://static.hltv.org/images/team/logo/8574" title="W7M"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           16
#          </span>
#          -
#          <span class="score-lost">
#           11
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="paiN" class="team-logo" src="https://static.hltv.org/images/team/logo/4773" title="paiN"/>
#           <div class="team">
#            paiN
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="Brasil Game Show 2019" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4509.png" title="Brasil Game Show 2019"/>
#          <span class="event-name">
#           Brasil Game Show 2019
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           inf
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#   </div>
#   <div class="results-sublist">
#    <span class="standard-headline">
#     Results for August 6th 2019
#    </span>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565126438000">
#     <a class="a-reset" href="/matches/2335240/winstrike-vs-bpro-ggbet-new-york-invitational-esl-one-new-york-2019-qualifier">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            Winstrike
#           </div>
#           <img alt="Winstrike" class="team-logo" src="https://static.hltv.org/images/team/logo/9183" title="Winstrike"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           2
#          </span>
#          -
#          <span class="score-lost">
#           0
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="Bpro" class="team-logo" src="https://static.hltv.org/images/team/logo/6762" title="Bpro"/>
#           <div class="team">
#            Bpro
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="GG.BET New York Invitational - ESL One New York 2019 Qualifier" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4773.png" title="GG.BET New York Invitational - ESL One New York 2019 Qualifier"/>
#          <span class="event-name">
#           GG.BET New York Invitational - ESL One New York 2019 Qualifier
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1565125661000">
#     <a class="a-reset" href="/matches/2335332/eox-vs-red-canids-brasil-game-show-2019">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
# ...
#           <div class="team">
#            Lucid Dream
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="MSI MGA 2019 Asia-Pacific Closed Qualifier" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4707.png" title="MSI MGA 2019 Asia-Pacific Closed Qualifier"/>
#          <span class="event-name">
#           MSI MGA 2019 Asia-Pacific Closed Qualifier
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1564811194000">
#     <a class="a-reset" href="/matches/2335276/ehome-vs-aster-msi-mga-2019-asia-pacific-closed-qualifier">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            EHOME
#           </div>
#           <img alt="EHOME" class="team-logo" src="https://static.hltv.org/images/team/logo/7024" title="EHOME"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           1
#          </span>
#          -
#          <span class="score-lost">
#           0
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="Aster" class="team-logo" src="https://static.hltv.org/images/team/logo/9868" title="Aster"/>
#           <div class="team">
#            Aster
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="MSI MGA 2019 Asia-Pacific Closed Qualifier" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4707.png" title="MSI MGA 2019 Asia-Pacific Closed Qualifier"/>
#          <span class="event-name">
#           MSI MGA 2019 Asia-Pacific Closed Qualifier
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#   </div>
#   <div class="results-sublist">
#    <span class="standard-headline">
#     Results for August 2nd 2019
#    </span>
#    <div class="result-con" data-zonedgrouping-entry-unix="1564777159000">
#     <a class="a-reset" href="/matches/2335291/5balls-vs-unique-cis-esports-pro-championship">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team">
#            5balls
#           </div>
#           <img alt="5balls" class="team-logo" src="https://static.hltv.org/images/team/logo/8589" title="5balls"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-lost">
#           8
#          </span>
#          -
#          <span class="score-won">
#           16
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="Unique" class="team-logo" src="https://static.hltv.org/images/team/logo/9287" title="Unique"/>
#           <div class="team team-won">
#            Unique
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="CIS Esports Pro Championship" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4778.png" title="CIS Esports Pro Championship"/>
#          <span class="event-name">
#           CIS Esports Pro Championship
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           mrg
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1564773550000">
#     <a class="a-reset" href="/matches/2335290/buaksib-vs-oneway-cis-esports-pro-championship">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            buaksib
#           </div>
#           <img alt="buaksib" class="team-logo" src="https://static.hltv.org/images/team/logo/10104" title="buaksib"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           16
#          </span>
#          -
#          <span class="score-lost">
#           13
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="OneWay" class="team-logo" src="https://static.hltv.org/images/team/logo/10129" title="OneWay"/>
#           <div class="team">
#            OneWay
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="CIS Esports Pro Championship" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4778.png" title="CIS Esports Pro Championship"/>
#          <span class="event-name">
#           CIS Esports Pro Championship
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           trn
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1564769943000">
#     <a class="a-reset" href="/matches/2335289/vega-squadron-vs-norbant-cis-esports-pro-championship">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            Vega Squadron
#           </div>
#           <img alt="Vega Squadron" class="team-logo" src="https://static.hltv.org/images/team/logo/6094" title="Vega Squadron"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           16
#          </span>
#          -
#          <span class="score-lost">
#           4
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="NorBant" class="team-logo" src="https://static.hltv.org/images/team/logo/9748" title="NorBant"/>
#           <div class="team">
#            NorBant
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="CIS Esports Pro Championship" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4778.png" title="CIS Esports Pro Championship"/>
#          <span class="event-name">
#           CIS Esports Pro Championship
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           ovp
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1564766115000">
#     <a class="a-reset" href="/matches/2335283/pro100-vs-unique-cis-esports-pro-championship">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            pro100
#           </div>
#           <img alt="pro100" class="team-logo" src="https://static.hltv.org/images/team/logo/7898" title="pro100"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           16
#          </span>
#          -
#          <span class="score-lost">
#           13
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="Unique" class="team-logo" src="https://static.hltv.org/images/team/logo/9287" title="Unique"/>
#           <div class="team">
#            Unique
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="CIS Esports Pro Championship" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4778.png" title="CIS Esports Pro Championship"/>
#          <span class="event-name">
#           CIS Esports Pro Championship
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           d2
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1564765200000">
#     <a class="a-reset" href="/matches/2335284/goliath-vs-big-5-syntech-masters">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team team-won">
#            Goliath
#           </div>
#           <img alt="Goliath" class="team-logo" src="https://static.hltv.org/images/team/logo/8193" title="Goliath"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-won">
#           2
#          </span>
#          -
#          <span class="score-lost">
#           1
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="Big 5" class="team-logo" src="https://static.hltv.org/images/team/logo/8111" title="Big 5"/>
#           <div class="team">
#            Big 5
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="Syntech Masters" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4788.png" title="Syntech Masters"/>
#          <span class="event-name">
#           Syntech Masters
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1564761451000">
#     <a class="a-reset" href="/matches/2335282/norbant-vs-gambit-youngsters-cis-esports-pro-championship">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team">
#            NorBant
#           </div>
#           <img alt="NorBant" class="team-logo" src="https://static.hltv.org/images/team/logo/9748" title="NorBant"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-lost">
#           5
#          </span>
#          -
#          <span class="score-won">
#           16
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="Gambit Youngsters" class="team-logo" src="https://static.hltv.org/images/team/logo/9976" title="Gambit Youngsters"/>
#           <div class="team team-won">
#            Gambit Youngsters
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="CIS Esports Pro Championship" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4778.png" title="CIS Esports Pro Championship"/>
#          <span class="event-name">
#           CIS Esports Pro Championship
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           mrg
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1564758461000">
#     <a class="a-reset" href="/matches/2335281/winstrike-vs-vega-squadron-cis-esports-pro-championship">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team">
#            Winstrike
#           </div>
#           <img alt="Winstrike" class="team-logo" src="https://static.hltv.org/images/team/logo/9183" title="Winstrike"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-lost">
#           10
#          </span>
#          -
#          <span class="score-won">
#           16
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="Vega Squadron" class="team-logo" src="https://static.hltv.org/images/team/logo/6094" title="Vega Squadron"/>
#           <div class="team team-won">
#            Vega Squadron
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="CIS Esports Pro Championship" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4778.png" title="CIS Esports Pro Championship"/>
#          <span class="event-name">
#           CIS Esports Pro Championship
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           ovp
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1564754703000">
#     <a class="a-reset" href="/matches/2335280/future-perfect-vs-oneway-cis-esports-pro-championship">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team">
#            Future Perfect
#           </div>
#           <img alt="Future Perfect" class="team-logo" src="https://static.hltv.org/images/team/logo/10228" title="Future Perfect"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-lost">
#           11
#          </span>
#          -
#          <span class="score-won">
#           16
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="OneWay" class="team-logo" src="https://static.hltv.org/images/team/logo/10129" title="OneWay"/>
#           <div class="team team-won">
#            OneWay
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="CIS Esports Pro Championship" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4778.png" title="CIS Esports Pro Championship"/>
#          <span class="event-name">
#           CIS Esports Pro Championship
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           d2
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#    <div class="result-con" data-zonedgrouping-entry-unix="1564752245000">
#     <a class="a-reset" href="/matches/2335140/havu-vs-kova-omen-by-hp-assembly-summer-2019">
#      <div class="result">
#       <table>
#        <tr>
#         <td class="team-cell">
#          <div class="line-align team1">
#           <div class="team">
#            HAVU
#           </div>
#           <img alt="HAVU" class="team-logo" src="https://static.hltv.org/images/team/logo/7865" title="HAVU"/>
#          </div>
#         </td>
#         <td class="result-score">
#          <span class="score-lost">
#           0
#          </span>
#          -
#          <span class="score-won">
#           2
#          </span>
#         </td>
#         <td class="team-cell">
#          <div class="line-align team2">
#           <img alt="KOVA" class="team-logo" src="https://static.hltv.org/images/team/logo/9648" title="KOVA"/>
#           <div class="team team-won">
#            KOVA
#           </div>
#          </div>
#         </td>
#         <td class="event">
#          <img alt="OMEN by HP Assembly Summer 2019" class="event-logo smartphone-only" src="https://static.hltv.org/images/eventLogos/4768.png" title="OMEN by HP Assembly Summer 2019"/>
#          <span class="event-name">
#           OMEN by HP Assembly Summer 2019
#          </span>
#         </td>
#         <td class="star-cell">
#          <div class="map-text">
#           bo3
#          </div>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </a>
#    </div>
#   </div>
#  </div>
#  <div class="pagination-component pagination-bottom">
#   <span class="pagination-data">
#    6001 - 6100 of 53075
#   </span>
#   <a class="pagination-prev" href="/results?offset=5900">
#    <i aria-hidden="true" class="fa fa-chevron-left pagination-left">
#    </i>
#   </a>
#   <a class="pagination-next" href="/results?offset=6100">
#    <i aria-hidden="true" class="fa fa-chevron-right pagination-right">
#    </i>
#   </a>
#  </div>
#  <span class="clearfix">
#  </span>
# </div>

# %%
#a class="a-reset" href
#class_='"a-reset" href' result-con
linktable=""
for Glink in foxtrot.find_all(class_='results-sublist'):
    for Finlink in Glink.find_all(class_='result-con'):
        dark = Finlink.find('a', href=True)
        superlink = dark['href']
        #print(superlink)
        ############
        http = 'https://www.hltv.org'+superlink
        source = requests.get(http).text
        soup = BeautifulSoup(source,'lxml')
        charlie = soup.find(class_='flexbox-column')
        tableT = ""
        tableCT = ""

        for Gmap in charlie.find_all(class_='mapholder'):
            Mapname = Gmap.find(class_='mapname').text
            for scoreFT in Gmap.find_all(class_='t'):
                alpha = (Mapname +","+ scoreFT.text + ",T side")
                tableT = tableT + alpha + '\n'

            for scoreFCT in Gmap.find_all(class_='ct'):
                beta = (Mapname +","+ scoreFCT.text + ",CT side")
                tableCT = tableCT + beta + '\n'
       #print(table)
        csgoTable = tableT + tableCT
        #print(csgoTable)
        
        ####################
        linktable = linktable + csgoTable

        
        
#print(charlie.prettify())
    
 #Fin_id = Finlink.split('"')
#Fin_id       
        
#gogo = Finlink.find('href',class_='a-reset')['href']
#        print(gogo)

# %%
print(linktable)
# Out:
# Inferno,12,T side
# Inferno,7,T side
# Mirage,5,T side
# Mirage,4,T side
# Inferno,3,CT side
# Inferno,4,CT side
# Mirage,10,CT side
# Mirage,11,CT side
# Mirage,14,T side
# Mirage,0,T side
# Dust2,10,T side
# Dust2,8,T side
# Mirage,1,CT side
# Mirage,2,CT side
# Dust2,5,CT side
# Dust2,6,CT side
# Mirage,11,T side
# Mirage,1,T side
# Inferno,11,T side
# Inferno,3,T side
# Mirage,4,CT side
# Mirage,5,CT side
# Inferno,4,CT side
# Inferno,5,CT side
# Train,4,T side
# Train,5,T side
# Mirage,11,T side
# Mirage,1,T side
# Train,11,CT side
# Train,6,CT side
# Mirage,4,CT side
# Mirage,5,CT side
# Mirage,8,T side
# Mirage,6,T side
# Inferno,5,T side
# Inferno,6,T side
# Mirage,7,CT side
# Mirage,8,CT side
# Inferno,10,CT side
# Inferno,5,CT side
# Train,11,T side
# Train,5,T side
# Nuke,8,T side
# Nuke,9,T side
# Train,4,CT side
# Train,5,CT side
# Nuke,7,CT side
# Nuke,0,CT side
# Dust2,10,T side
# Dust2,10,T side
# Mirage,6,T side
# Mirage,6,T side
# Dust2,5,CT side
# Dust2,5,CT side
# Mirage,9,CT side
# Mirage,9,CT side
# Dust2,6,T side
# Dust2,7,T side
# Vertigo,10,T side
# Vertigo,5,T side
# Dust2,9,CT side
# Dust2,7,CT side
# Vertigo,5,CT side
# Vertigo,6,CT side
# Train,2,T side
# Train,3,T side
# Nuke,10,T side
# Nuke,5,T side
# Train,13,CT side
# Train,3,CT side
# Nuke,5,CT side
# Nuke,6,CT side
# Dust2,6,T side
# Dust2,7,T side
# Mirage,10,T side
# Mirage,2,T side
# Dust2,9,CT side
# Dust2,5,CT side
# Mirage,5,CT side
# Mirage,6,CT side
# Inferno,9,T side
# Inferno,1,T side
# Nuke,11,T side
# Nuke,12,T side
# Train,2,T side
# Train,3,T side
# Inferno,6,CT side
# Inferno,7,CT side
# Nuke,4,CT side
# Nuke,3,CT side
# Train,13,CT side
# Train,3,CT side
# Overpass,6,T side
# Overpass,3,T side
# Nuke,7,T side
# Nuke,8,T side
# Inferno,7,T side
# Inferno,8,T side
# Overpass,9,CT side
# Overpass,10,CT side
# Nuke,8,CT side
# Nuke,6,CT side
# Inferno,8,CT side
# Inferno,7,CT side
# Inferno,7,T side
# Inferno,8,T side
# Inferno,8,CT side
# Inferno,7,CT side
# Inferno,4,T side
# Inferno,5,T side
# Overpass,9,T side
# Overpass,9,T side
# Inferno,11,CT side
# Inferno,0,CT side
# Overpass,6,CT side
# Overpass,6,CT side
# Overpass,7,T side
# Overpass,5,T side
# Inferno,12,T side
# Inferno,12,T side
# Nuke,9,T side
# Nuke,9,T side
# Overpass,8,CT side
# Overpass,9,CT side
# Inferno,3,CT side
# Inferno,3,CT side
# Nuke,6,CT side
# Nuke,6,CT side
# Inferno,8,T side
# Inferno,9,T side
# Inferno,7,CT side
# Inferno,6,CT side
# Nuke,13,T side
# Nuke,2,T side
# Nuke,2,CT side
# Nuke,3,CT side
# Dust2,4,T side
# Dust2,5,T side
# Dust2,11,CT side
# Dust2,2,CT side
# Overpass,8,T side
# Overpass,6,T side
# Vertigo,9,T side
# Vertigo,8,T side
# Inferno,7,T side
# Inferno,7,T side
# Overpass,7,CT side
# Overpass,8,CT side
# Vertigo,6,CT side
# Vertigo,7,CT side
# Inferno,8,CT side
# Inferno,8,CT side
# Mirage,7,T side
# Mirage,7,T side
# Train,7,T side
# Train,6,T side
# Mirage,8,CT side
# Mirage,8,CT side
# Train,8,CT side
# Train,9,CT side
# Nuke,5,T side
# Nuke,6,T side
# Overpass,7,T side
# Overpass,8,T side
# Nuke,10,CT side
# Nuke,4,CT side
# Overpass,8,CT side
# Overpass,2,CT side
# Vertigo,9,T side
# Vertigo,6,T side
# Mirage,3,T side
# Mirage,4,T side
# Vertigo,6,CT side
# Vertigo,7,CT side
# Mirage,12,CT side
# Mirage,5,CT side
# Overpass,11,T side
# Overpass,1,T side
# Dust2,9,T side
# Dust2,9,T side
# Overpass,4,CT side
# Overpass,5,CT side
# Dust2,6,CT side
# Dust2,6,CT side
# Nuke,6,T side
# Nuke,7,T side
# Overpass,6,T side
# Overpass,7,T side
# Nuke,9,CT side
# Nuke,5,CT side
# Overpass,9,CT side
# Overpass,5,CT side
# Overpass,1,T side
# Overpass,2,T side
# Inferno,7,T side
# Inferno,8,T side
# Overpass,14,CT side
# Overpass,0,CT side
# Inferno,8,CT side
# Inferno,5,CT side
# Dust2,5,T side
# Dust2,6,T side
# Train,9,T side
# Train,3,T side
# Dust2,10,CT side
# Dust2,8,CT side
# Train,6,CT side
# Train,7,CT side
# Inferno,1,T side
# Inferno,2,T side
# Mirage,1,T side
# Mirage,2,T side
# Inferno,14,CT side
# Inferno,1,CT side
# Mirage,14,CT side
# Mirage,0,CT side
# Train,5,T side
# Train,5,T side
# Vertigo,9,T side
# Vertigo,2,T side
# Mirage,8,T side
# Mirage,9,T side
# Train,10,CT side
# Train,10,CT side
# Vertigo,6,CT side
# Vertigo,7,CT side
# Mirage,7,CT side
# Mirage,3,CT side
# Train,10,T side
# Train,9,T side
# Nuke,9,T side
# Nuke,2,T side
# Overpass,6,T side
# Overpass,4,T side
# Train,5,CT side
# Train,6,CT side
# Nuke,6,CT side
# Nuke,7,CT side
# Overpass,9,CT side
# Overpass,10,CT side
# Inferno,10,T side
# Inferno,6,T side
# Overpass,2,T side
# Overpass,3,T side
# Nuke,10,T side
# Nuke,5,T side
# Inferno,5,CT side
# Inferno,6,CT side
# Overpass,13,CT side
# Overpass,8,CT side
# Nuke,5,CT side
# Nuke,6,CT side
# Dust2,9,T side
# Dust2,3,T side
# Nuke,5,T side
# Nuke,2,T side
# Overpass,7,T side
# Overpass,6,T side
# Dust2,6,CT side
# Dust2,7,CT side
# Nuke,10,CT side
# Nuke,11,CT side
# Overpass,8,CT side
# Overpass,9,CT side
# Nuke,9,T side
# Nuke,9,T side
# Inferno,5,T side
# Inferno,6,T side
# Nuke,6,CT side
# Nuke,6,CT side
# Inferno,10,CT side
# Inferno,8,CT side
# Inferno,9,T side
# Inferno,10,T side
# Nuke,8,T side
# Nuke,9,T side
# Dust2,8,T side
# Dust2,8,T side
# Inferno,6,CT side
# Inferno,5,CT side
# Nuke,7,CT side
# Nuke,6,CT side
# Dust2,7,CT side
# Dust2,7,CT side
# Inferno,7,T side
# Inferno,8,T side
# Dust2,2,T side
# Dust2,3,T side
# Overpass,10,T side
# Overpass,9,T side
# Inferno,8,CT side
# Inferno,6,CT side
# Dust2,13,CT side
# Dust2,2,CT side
# Overpass,5,CT side
# Overpass,6,CT side
# Nuke,7,T side
# Nuke,7,T side
# Overpass,7,T side
# Overpass,7,T side
# Inferno,3,T side
# Inferno,4,T side
# Nuke,8,CT side
# Nuke,8,CT side
# Overpass,8,CT side
# Overpass,8,CT side
# Inferno,12,CT side
# Inferno,2,CT side
# Train,10,T side
# Train,2,T side
# Vertigo,9,T side
# Vertigo,7,T side
# Train,5,CT side
# Train,6,CT side
# Vertigo,6,CT side
# Vertigo,7,CT side
# Vertigo,9,T side
# Vertigo,3,T side
# Inferno,9,T side
# Inferno,10,T side
# Vertigo,6,CT side
# Vertigo,7,CT side
# Inferno,6,CT side
# Inferno,4,CT side
# Mirage,5,T side
# Mirage,6,T side
# Train,8,T side
# Train,8,T side
# Mirage,10,CT side
# Mirage,2,CT side
# Train,7,CT side
# Train,7,CT side
# Nuke,8,T side
# Nuke,0,T side
# Inferno,9,T side
# Inferno,3,T side
# Nuke,7,CT side
# Nuke,8,CT side
# Inferno,6,CT side
# Inferno,7,CT side
# Vertigo,12,T side
# Vertigo,0,T side
# Train,7,T side
# Train,5,T side
# Vertigo,3,CT side
# Vertigo,4,CT side
# Train,8,CT side
# Train,9,CT side
# Inferno,12,T side
# Inferno,6,T side
# Mirage,10,T side
# Mirage,2,T side
# Inferno,3,CT side
# Inferno,4,CT side
# Mirage,5,CT side
# Mirage,6,CT side
# Nuke,1,T side
# Nuke,2,T side
# Nuke,14,CT side
# Nuke,1,CT side
# Train,8,T side
# Train,9,T side
# Inferno,7,T side
# Inferno,3,T side
# Train,7,CT side
# Train,3,CT side
# Inferno,8,CT side
# Inferno,9,CT side
# Mirage,3,T side
# Mirage,4,T side
# Mirage,12,CT side
# Mirage,3,CT side
# Inferno,5,T side
# Inferno,6,T side
# Vertigo,3,T side
# Vertigo,4,T side
# Inferno,10,CT side
# Inferno,0,CT side
# Vertigo,12,CT side
# Vertigo,0,CT side
# Train,4,T side
# Train,5,T side
# Train,11,CT side
# Train,1,CT side
# Inferno,4,T side
# Inferno,5,T side
# Mirage,6,T side
# Mirage,7,T side
# Inferno,11,CT side
# Inferno,7,CT side
# Mirage,9,CT side
# Mirage,5,CT side
# Dust2,1,T side
# Dust2,2,T side
# Train,6,T side
# Train,7,T side
# Dust2,14,CT side
# Dust2,0,CT side
# Train,9,CT side
# Train,2,CT side
# Nuke,13,T side
# Nuke,2,T side
# Vertigo,10,T side
# Vertigo,1,T side
# Nuke,2,CT side
# Nuke,3,CT side
# Vertigo,5,CT side
# Vertigo,6,CT side
# Mirage,6,T side
# Mirage,7,T side
# Mirage,9,CT side
# Mirage,2,CT side
# Mirage,5,T side
# Mirage,6,T side
# Nuke,8,T side
# Nuke,0,T side
# Mirage,10,CT side
# Mirage,4,CT side
# Nuke,7,CT side
# Nuke,8,CT side
# Train,9,T side
# Train,9,T side
# Vertigo,5,T side
# Vertigo,6,T side
# Overpass,11,T side
# Overpass,6,T side
# Train,6,CT side
# Train,6,CT side
# Vertigo,10,CT side
# Vertigo,8,CT side
# Overpass,4,CT side
# Overpass,5,CT side
# Vertigo,10,T side
# Vertigo,10,T side
# Mirage,11,T side
# Mirage,6,T side
# Inferno,11,T side
# Inferno,2,T side
# Vertigo,5,CT side
# Vertigo,5,CT side
# Mirage,4,CT side
# Mirage,5,CT side
# Inferno,4,CT side
# Inferno,5,CT side
# Overpass,4,T side
# Overpass,4,T side
# Train,6,T side
# Train,7,T side
# Inferno,4,T side
# Inferno,5,T side
# Overpass,11,CT side
# Overpass,11,CT side
# Train,9,CT side
# Train,4,CT side
# Inferno,11,CT side
# Inferno,2,CT side
# Vertigo,12,T side
# Vertigo,13,T side
# Nuke,6,T side
# Nuke,7,T side
# Vertigo,3,CT side
# Vertigo,2,CT side
# Nuke,9,CT side
# Nuke,8,CT side
# Vertigo,5,T side
# Vertigo,6,T side
# Nuke,6,T side
# Nuke,7,T side
# Train,10,T side
# Train,10,T side
# Vertigo,10,CT side
# Vertigo,5,CT side
# Nuke,9,CT side
# Nuke,5,CT side
# Train,5,CT side
# Train,5,CT side
# Overpass,6,T side
# Overpass,7,T side
# Vertigo,6,T side
# Vertigo,6,T side
# Inferno,5,T side
# Inferno,6,T side
# Overpass,9,CT side
# Overpass,4,CT side
# Vertigo,9,CT side
# Vertigo,9,CT side
# Inferno,10,CT side
# Inferno,5,CT side
# Inferno,8,T side
# Inferno,9,T side
# Nuke,6,T side
# Nuke,2,T side
# Overpass,7,T side
# Overpass,8,T side
# Inferno,7,CT side
# Inferno,6,CT side
# Nuke,9,CT side
# Nuke,10,CT side
# Overpass,8,CT side
# Overpass,4,CT side
# Overpass,10,T side
# Overpass,2,T side
# Inferno,5,T side
# Inferno,6,T side
# Nuke,7,T side
# Nuke,7,T side
# Overpass,5,CT side
# Overpass,6,CT side
# Inferno,10,CT side
# Inferno,3,CT side
# Nuke,8,CT side
# Nuke,8,CT side
# Dust2,9,T side
# Dust2,9,T side
# Inferno,7,T side
# Inferno,8,T side
# Train,11,T side
# Train,0,T side
# Dust2,6,CT side
# Dust2,6,CT side
# Inferno,8,CT side
# Inferno,3,CT side
# Train,4,CT side
# Train,5,CT side
# Mirage,8,T side
# Mirage,7,T side
# Dust2,7,T side
# Dust2,8,T side
# Overpass,10,T side
# Overpass,3,T side
# Mirage,7,CT side
# Mirage,8,CT side
# Dust2,8,CT side
# Dust2,7,CT side
# Overpass,5,CT side
# Overpass,6,CT side
# Mirage,3,T side
# Mirage,4,T side
# Nuke,2,T side
# Nuke,3,T side
# Mirage,12,CT side
# Mirage,9,CT side
# Nuke,13,CT side
# Nuke,2,CT side
# Nuke,8,T side
# Nuke,6,T side
# Inferno,10,T side
# Inferno,11,T side
# Mirage,9,T side
# Mirage,10,T side
# Nuke,7,CT side
# Nuke,8,CT side
# Inferno,5,CT side
# Inferno,4,CT side
# Mirage,6,CT side
# Mirage,3,CT side
# Mirage,5,T side
# Mirage,6,T side
# Nuke,2,T side
# Nuke,3,T side
# Mirage,10,CT side
# Mirage,9,CT side
# Nuke,13,CT side
# Nuke,2,CT side
# Nuke,10,T side
# Nuke,10,T side
# Mirage,4,T side
# Mirage,5,T side
# Nuke,5,CT side
# Nuke,5,CT side
# Mirage,11,CT side
# Mirage,7,CT side
# Train,5,T side
# Train,6,T side
# Overpass,10,T side
# Overpass,5,T side
# Train,10,CT side
# Train,9,CT side
# Overpass,5,CT side
# Overpass,6,CT side
# Nuke,6,T side
# Nuke,7,T side
# Inferno,8,T side
# Inferno,3,T side
# Nuke,9,CT side
# Nuke,6,CT side
# Inferno,7,CT side
# Inferno,8,CT side
# Mirage,5,T side
# Mirage,6,T side
# Overpass,7,T side
# Overpass,8,T side
# Mirage,10,CT side
# Mirage,5,CT side
# Overpass,8,CT side
# Overpass,1,CT side
# Mirage,8,T side
# Mirage,3,T side
# Overpass,10,T side
# Overpass,2,T side
# Mirage,7,CT side
# Mirage,8,CT side
# Overpass,5,CT side
# Overpass,6,CT side
# Dust2,12,T side
# Dust2,0,T side
# Train,11,T side
# Train,3,T side
# Dust2,3,CT side
# Dust2,4,CT side
# Train,4,CT side
# Train,5,CT side
# Dust2,7,T side
# Dust2,5,T side
# Vertigo,7,T side
# Vertigo,4,T side
# Dust2,8,CT side
# Dust2,9,CT side
# Vertigo,8,CT side
# Vertigo,9,CT side
# Inferno,11,T side
# Inferno,8,T side
# Mirage,5,T side
# Mirage,4,T side
# Dust2,9,T side
# Dust2,0,T side
# Inferno,4,CT side
# Inferno,5,CT side
# Mirage,10,CT side
# Mirage,11,CT side
# Dust2,6,CT side
# Dust2,7,CT side
# Inferno,6,T side
# Inferno,7,T side
# Train,7,T side
# Train,8,T side
# Dust2,11,T side
# Dust2,1,T side
# Inferno,9,CT side
# Inferno,7,CT side
# Train,8,CT side
# Train,7,CT side
# Dust2,4,CT side
# Dust2,5,CT side
# Mirage,8,T side
# Mirage,9,T side
# Mirage,7,CT side
# Mirage,0,CT side
# Inferno,11,T side
# Inferno,0,T side
# Nuke,8,T side
# Nuke,9,T side
# Inferno,4,CT side
# Inferno,5,CT side
# Nuke,7,CT side
# Nuke,4,CT side
# Nuke,4,T side
# Nuke,5,T side
# Inferno,7,T side
# Inferno,3,T side
# Nuke,11,CT side
# Nuke,6,CT side
# Inferno,8,CT side
# Inferno,9,CT side
# Overpass,9,T side
# Overpass,2,T side
# Mirage,6,T side
# Mirage,5,T side
# Inferno,8,T side
# Inferno,7,T side
# Overpass,6,CT side
# Overpass,7,CT side
# Mirage,9,CT side
# Mirage,10,CT side
# Inferno,7,CT side
# Inferno,8,CT side
# Nuke,3,T side
# Nuke,4,T side
# Train,3,T side
# Train,4,T side
# Nuke,12,CT side
# Nuke,0,CT side
# Train,12,CT side
# Train,1,CT side
# Nuke,8,T side
# Nuke,2,T side
# Overpass,11,T side
# Overpass,11,T side
# Nuke,7,CT side
# Nuke,8,CT side
# Overpass,4,CT side
# Overpass,4,CT side
# Dust2,11,T side
# Dust2,7,T side
# Dust2,4,CT side
# Dust2,5,CT side
# Mirage,9,T side
# Mirage,1,T side
# Mirage,6,CT side
# Mirage,7,CT side
# Overpass,8,T side
# Overpass,6,T side
# Overpass,7,CT side
# Overpass,8,CT side
# Inferno,6,T side
# Inferno,7,T side
# Inferno,9,CT side
# Inferno,2,CT side
# Inferno,10,T side
# Inferno,9,T side
# Train,9,T side
# Train,5,T side
# Dust2,8,T side
# Dust2,9,T side
# Inferno,5,CT side
# Inferno,6,CT side
# Train,6,CT side
# Train,7,CT side
# Dust2,7,CT side
# Dust2,6,CT side
# Nuke,7,T side
# Nuke,8,T side
# Nuke,8,CT side
# Nuke,6,CT side
# Overpass,3,T side
# Overpass,4,T side
# Overpass,12,CT side
# Overpass,0,CT side
# Train,6,T side
# Train,7,T side
# Overpass,3,T side
# Overpass,4,T side
# Train,9,CT side
# Train,2,CT side
# Overpass,12,CT side
# Overpass,2,CT side
# Dust2,2,T side
# Dust2,3,T side
# Dust2,13,CT side
# Dust2,4,CT side
# Nuke,11,T side
# Nuke,1,T side
# Nuke,4,CT side
# Nuke,5,CT side
# Dust2,7,T side
# Dust2,7,T side
# Dust2,8,CT side
# Dust2,8,CT side
# Nuke,1,T side
# Nuke,2,T side
# Nuke,14,CT side
# Nuke,0,CT side
# Inferno,13,T side
# Inferno,3,T side
# Inferno,2,CT side
# Inferno,3,CT side
# Vertigo,13,T side
# Vertigo,0,T side
# Vertigo,2,CT side
# Vertigo,3,CT side
# Train,2,T side
# Train,3,T side
# Train,13,CT side
# Train,3,CT side
# Dust2,7,T side
# Dust2,8,T side
# Dust2,8,CT side
# Dust2,4,CT side
# Dust2,9,T side
# Dust2,4,T side
# Dust2,6,CT side
# Dust2,7,CT side

# %%
csvname = "CSGOdataset7.csv"
j=[0,1]
for i in j:
    file=open(csvname,"wb")
    file.write(bytes(linktable,encoding="ascii",errors="ignore"))

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-f69bb99d7da4> in <module>
#       2 tableCT = ""
#       3
# ----> 4 for Gmap in charlie.find_all(class_='mapholder'):
#       5     Mapname = Gmap.find(class_='mapname').text
#       6     for scoreFT in Gmap.find_all(class_='t'):
#
# NameError: name 'charlie' is not defined

# %%
#csgoTable = "Map,Number of Wins,Side\n"+csgoTable

#####score = (score).replace(':',',')
    #score = (score).replace(';',',')
    #score = (score).replace('(','')
    #score = (score).replace(')','')
    #score = (score).replace(' ','')
    #score
#table1 = (Gmap+","+score)

#csgoTable

# %%
df = pd.read_csv('CSGOdataset1.csv')
#df.columns=["MapName","Wins","Side"]
#df.head

df.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-55188ffd7861> in <module>
# ----> 1 df = pd.read_csv('CSGOdataset1.csv')
#       2 #df.columns=["MapName","Wins","Side"]
#       3 #df.head
#       4
#       5 df.head(20)
#
# NameError: name 'pd' is not defined
